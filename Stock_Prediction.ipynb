# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/19O4w8F-wQ3BqszS0K6Dn2GCG_Z4SLiIO)
#
# In this notebook, I am going to explore stock price prediction using five methods:
#
# * Linear Regression using $L_2$ regularization or ***Ridge Regression***
# * ***Lasso***
# * ***LARSLasso***
# * ***Gradient Boosting Regressors***
# * *Neural Network based approaches using 1D Convolutions, LSTM layers with a Huber loss*
#
# The source of the stock prices is from Yahoo Finance. I downloaded  stock prices for Motorola Inc. since September 5th 2010 untill September 5th, 2019).  The variable to predict is the ***Adjusted Close*** price.
#
# I am running this on Google Colab, and switch runtime to GPU so it will train much faster.

# %% [markdown]
# Let's import all of the necessary packages we need, which include NumPy, Pandas, Matplotlib, Scikit-learn and Keras/Tensorflow.

# %%
# Import necessary packages
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import sklearn
from sklearn.linear_model import Ridge
from sklearn import linear_model
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv1D, LSTM, Dense
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.losses import Huber
from keras.optimizers import SGD

# %% [markdown]
# I have downloaded the Motorola solutions stock price data to my computer from Yahoo Finance. After that I uploaded the csv file in my github repository, got the raw url and used Pandas to read in the data and set the independent variable to be the Date. Let's also take a look at the first few entries

# %%
url = 'https://raw.githubusercontent.com/bulavk1n/stock-prediction/master/MSI.csv'
df = pd.read_csv(url)

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2010-09-07  32.057026  32.057026  31.288950  31.652775  26.948092  3877000
# 2010-09-08  31.693199  32.461273  31.491076  32.259151  27.464342  5852600
# 2010-09-09  32.461273  32.905949  32.016602  32.259151  27.464342  4212500
# 2010-09-10  32.097450  32.663399  31.814474  32.016602  27.257839  5931000
# 2010-09-13  32.340000  33.552750  32.218723  33.471901  28.496838  7679200

# %% [markdown]
# Let's take a look at how the prices looks like each day since the beginning up to this point with the date on the x-axis and the price on the y-axis.

# %%
df['Adj Close'].plot(label='MSI', figsize=(16,4), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# To make this more robust to noise and to leverage past values, we will not use the date to predict the stock prices, but we will use batches of 32 prices where each training example, we leverage 32 prices from the past to predict the price on the 33rd day.  We will thus have $N - 32$ training examples with $N$ being the number of days we've downloaded for the stock data.  We will thus create a 2D matrix of training samples with each row being the prices 32 consecutive days in the past with the price to predict being the current day.

# %%
window_size = 32 # Allow us to look at 32 days into the past
# Prepare the data so that we have 32 day windows and predict what the next day should be

# Get indices of access for the data
num_samples = len(df) - window_size
indices = np.arange(num_samples).astype(np.int)[:,None] + np.arange(window_size + 1).astype(np.int)

# %%
data = df['Adj Close'].values[indices] # Create the 2D matrix of training samples

# %% [markdown]
# We create a 2D matrix such that we have 33 columns per example.  The training samples will be the first 32 columns with the target variable being the last column.

# %%
X = data[:,:-1] # Each row represents 32 days in the past
y = data[:,-1] # Each output value represents the 33rd day

# %% [markdown]
# Perform train/test split such that the first 80% of the prices is the training set and the last 20% of the prices is the test dataset.  We will train on the training set and test the performance on the test set to see how well we can forecast the price for Tesla stock.

# %%
# Train and test split
split_fraction = 0.8
ind_split = int(split_fraction * num_samples)
X_train = X[:ind_split]
y_train = y[:ind_split]
X_test = X[ind_split:]
y_test = y[ind_split:]

# %% [markdown]
# # Method #1 - Ridge Regression
#
# We will use the Ridge Regression method from Scikit-learn where we'll train and perform inference on the training and test data respectively.  Let's also plot how it compares with the actual data for both training and test.

# %%
# Train
ridge_model = Ridge()
ridge_model.fit(X_train, y_train)

# Infer
y_pred_train_ridge = ridge_model.predict(X_train)
y_pred_ridge = ridge_model.predict(X_test)

# %%
# Plot what it looks like for the training data
df_ridge = df.copy()
df_ridge.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_ridge = df_ridge.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_ridge['Adj Close Train'] = y_pred_train_ridge[:-window_size]
df_ridge.plot(label='MSI', figsize=(16,4), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# OK... not bad and very frighteningly close.  We may be overfitting.  Let's check out the test data.

# %%
# Same for the test
df_ridge = df.copy()
df_ridge.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_ridge = df_ridge.iloc[ind_split+window_size:]
df_ridge['Adj Close Test'] = y_pred_ridge
df_ridge.plot(label='MSI', figsize=(16,4), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# # Method #2 - Lasso
# The Lasso is a linear model that estimates sparse coefficients. It is useful in some contexts due to its tendency to prefer solutions with fewer non-zero coefficients, effectively reducing the number of features upon which the given solution is dependent. For this reason Lasso and its variants are fundamental to the field of compressed sensing. Under certain conditions, it can recover the exact set of non-zero coefficients

# %%
# Train
lasso_model = linear_model.Lasso(alpha=0.1)
lasso_model.fit(X_train, y_train)

# Infer
y_pred_train_lasso = lasso_model.predict(X_train)
y_pred_lasso = lasso_model.predict(X_test)

# %%
# Plot what it looks like for the training data
df_lasso = df.copy()
df_lasso.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_lasso = df_lasso.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_lasso['Adj Close Train'] = y_pred_train_lasso[:-window_size]
df_lasso.plot(label='MSI', figsize=(16,4), title='Adjusted Closing Price', grid=True)

# %%
# Same for the test
df_lasso = df.copy()
df_lasso.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_lasso = df_lasso.iloc[ind_split+window_size:]
df_lasso['Adj Close Test'] = y_pred_lasso
df_lasso.plot(label='MSI', figsize=(16,4), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# # Method #3 - LARS Lasso
#
# LassoLars is a lasso model implemented using the LARS algorithm, and unlike the implementation based on coordinate descent, this yields the exact solution, which is piecewise linear as a function of the norm of its coefficients.

# %%
# Train
larslasso_model = linear_model.LassoLars(alpha=.1)
larslasso_model.fit(X_train, y_train)

# Infer
y_pred_train_larslasso = larslasso_model.predict(X_train)
y_pred_larslasso = larslasso_model.predict(X_test)

# %%
# Plot what it looks like for the training data
df_larslasso = df.copy()
df_larslasso.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_larslasso = df_larslasso.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_larslasso['Adj Close Train'] = y_pred_train_larslasso[:-window_size]
df_larslasso.plot(label='MSI', figsize=(16,4), title='Adjusted Closing Price', grid=True)

# %%
# Same for the test
df_larslasso = df.copy()
df_larslasso.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_larslasso = df_larslasso.iloc[ind_split+window_size:]
df_larslasso['Adj Close Test'] = y_pred_larslasso
df_larslasso.plot(label='MSI', figsize=(16,4), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Wow... ok let's move on.
#
# # Method #4 - Gradient Boosting Trees
#
# Let's apply the same methodology from Method #1 to Gradient Boosting Trees in Scikit-learn.

# %%
# Model #2 - Gradient Boosting Trees
gb_model = GradientBoostingRegressor()
gb_model.fit(X_train, y_train)

# Infer
y_pred_train_gb = gb_model.predict(X_train)
y_pred_gb = gb_model.predict(X_test)

# %%
# Plot what it looks like for the training data
df_gb = df.copy()
df_gb.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_gb = df_gb.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_gb['Adj Close Train'] = y_pred_train_gb[:-window_size]
df_gb.plot(label='MSI', figsize=(16,8), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Again... frighteningly similar.  Let's check the test data.

# %%
# Same for the test
df_gb = df.copy()
df_gb.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_gb = df_gb.iloc[ind_split+window_size:] 
df_gb['Adj Close Test'] = y_pred_gb
df_gb.plot(label='MSI', figsize=(16,4), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# # Method #5 - Using neural networks with 1D convolutional and LSTM layers
#
# The last method we'll use is a neural network based one using Keras / Tensorflow.  We use a stack of Conv1D and LSTM layers, followed by Dense layers lastly followed by a linear layer to predict the stock price.

# %%
# Model #3 - Using RNNs
keras_model = Sequential([
  Conv1D(filters=128, kernel_size=5, input_shape=(window_size, 1), strides=1, padding="causal", activation="tanh"),
  Conv1D(filters=128, kernel_size=5, strides=1, padding="causal", activation="tanh"),
  LSTM(128, return_sequences=True),
  LSTM(128),
  Dense(64, activation="tanh"),
  Dense(64, activation="tanh"),
  Dense(1)
])

keras_model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 32, 128)           768
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 32, 128)           82048
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32, 128)           131584
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               131584
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 358,465
# Trainable params: 358,465
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# This is a technique to find the optimal learning rate for the neural network.  Specifically we gradually increase the learning rate at each epoch, recording the loss for each then choosing the learning rate that has the smallest loss overall.
#
# Also, neural networks learn better when the data is normalized so we will normalize the data to the $[-1,1]$ range by using Scikit-learn's `MinMaxScaler`.  Therefore, we need to find apply this scaling on all of the price data, then decompose it into the training and test sets again.

# %%
# First figure out the right learning rate
lr_schedule = LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20))
optimizer = SGD(lr=1e-8, momentum=0.9)
keras_model.compile(loss=Huber(),
                    optimizer=optimizer,
                    metrics=["mae"])
# Scale the data due to LSTM units
scaler = MinMaxScaler(feature_range=(-1, 1))
data_transform = scaler.fit_transform(df['Adj Close'].values[:,None])
data_transform = data_transform[indices]
X2 = data_transform[:,:-1]
y2 = data_transform[:,-1]
X_train_reshape = X2[:ind_split]
y_train_reshape = y2[:ind_split]
X_test_reshape = X2[ind_split:]
y_test_reshape = y2[ind_split:]
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# We now try and find the optimal learning rate.  If you're using Google Colab, this will take ~4 minutes.

# %%
history = keras_model.fit(X_train_reshape, y_train_reshape, batch_size=256, epochs=250, callbacks=[lr_schedule], validation_data=(X_test_reshape, y_test_reshape))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 1785 samples, validate on 447 samples
# Epoch 1/250
# 1785/1785 [==============================] - 10s 5ms/step - loss: 0.2073 - mean_absolute_error: 0.6144 - val_loss: 0.0859 - val_mean_absolute_error: 0.3148
# Epoch 2/250
# 1785/1785 [==============================] - 1s 642us/step - loss: 0.2073 - mean_absolute_error: 0.6144 - val_loss: 0.0859 - val_mean_absolute_error: 0.3148
# Epoch 3/250
# 1785/1785 [==============================] - 1s 611us/step - loss: 0.2073 - mean_absolute_error: 0.6144 - val_loss: 0.0859 - val_mean_absolute_error: 0.3148
# Epoch 4/250
# 1785/1785 [==============================] - 1s 614us/step - loss: 0.2073 - mean_absolute_error: 0.6144 - val_loss: 0.0859 - val_mean_absolute_error: 0.3148
# Epoch 5/250
# 1785/1785 [==============================] - 1s 636us/step - loss: 0.2073 - mean_absolute_error: 0.6144 - val_loss: 0.0859 - val_mean_absolute_error: 0.3148
# Epoch 6/250
# 1785/1785 [==============================] - 1s 634us/step - loss: 0.2072 - mean_absolute_error: 0.6144 - val_loss: 0.0859 - val_mean_absolute_error: 0.3148
# Epoch 7/250
# 1785/1785 [==============================] - 1s 618us/step - loss: 0.2072 - mean_absolute_error: 0.6144 - val_loss: 0.0859 - val_mean_absolute_error: 0.3148
# Epoch 8/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 0.2072 - mean_absolute_error: 0.6144 - val_loss: 0.0859 - val_mean_absolute_error: 0.3148
# Epoch 9/250
# 1785/1785 [==============================] - 1s 653us/step - loss: 0.2072 - mean_absolute_error: 0.6144 - val_loss: 0.0859 - val_mean_absolute_error: 0.3149
# Epoch 10/250
# 1785/1785 [==============================] - 1s 652us/step - loss: 0.2072 - mean_absolute_error: 0.6144 - val_loss: 0.0859 - val_mean_absolute_error: 0.3149
# Epoch 11/250
# 1785/1785 [==============================] - 1s 664us/step - loss: 0.2072 - mean_absolute_error: 0.6144 - val_loss: 0.0859 - val_mean_absolute_error: 0.3149
# Epoch 12/250
# 1785/1785 [==============================] - 1s 646us/step - loss: 0.2072 - mean_absolute_error: 0.6144 - val_loss: 0.0859 - val_mean_absolute_error: 0.3149
# Epoch 13/250
# 1785/1785 [==============================] - 1s 651us/step - loss: 0.2072 - mean_absolute_error: 0.6144 - val_loss: 0.0860 - val_mean_absolute_error: 0.3149
# Epoch 14/250
# 1785/1785 [==============================] - 1s 642us/step - loss: 0.2072 - mean_absolute_error: 0.6143 - val_loss: 0.0860 - val_mean_absolute_error: 0.3149
# Epoch 15/250
# 1785/1785 [==============================] - 1s 654us/step - loss: 0.2072 - mean_absolute_error: 0.6143 - val_loss: 0.0860 - val_mean_absolute_error: 0.3149
# Epoch 16/250
# 1785/1785 [==============================] - 1s 662us/step - loss: 0.2072 - mean_absolute_error: 0.6143 - val_loss: 0.0860 - val_mean_absolute_error: 0.3149
# Epoch 17/250
# 1785/1785 [==============================] - 1s 668us/step - loss: 0.2072 - mean_absolute_error: 0.6143 - val_loss: 0.0860 - val_mean_absolute_error: 0.3149
# Epoch 18/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 0.2072 - mean_absolute_error: 0.6143 - val_loss: 0.0860 - val_mean_absolute_error: 0.3149
# Epoch 19/250
# 1785/1785 [==============================] - 1s 651us/step - loss: 0.2072 - mean_absolute_error: 0.6143 - val_loss: 0.0860 - val_mean_absolute_error: 0.3149
# Epoch 20/250
# 1785/1785 [==============================] - 1s 725us/step - loss: 0.2072 - mean_absolute_error: 0.6143 - val_loss: 0.0860 - val_mean_absolute_error: 0.3149
# Epoch 21/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 0.2071 - mean_absolute_error: 0.6142 - val_loss: 0.0860 - val_mean_absolute_error: 0.3149
# Epoch 22/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 0.2071 - mean_absolute_error: 0.6142 - val_loss: 0.0860 - val_mean_absolute_error: 0.3149
# Epoch 23/250
# 1785/1785 [==============================] - 1s 666us/step - loss: 0.2071 - mean_absolute_error: 0.6142 - val_loss: 0.0860 - val_mean_absolute_error: 0.3150
# Epoch 24/250
# 1785/1785 [==============================] - 1s 659us/step - loss: 0.2071 - mean_absolute_error: 0.6142 - val_loss: 0.0860 - val_mean_absolute_error: 0.3150
# Epoch 25/250
# 1785/1785 [==============================] - 1s 694us/step - loss: 0.2071 - mean_absolute_error: 0.6141 - val_loss: 0.0860 - val_mean_absolute_error: 0.3150
# Epoch 26/250
# 1785/1785 [==============================] - 1s 679us/step - loss: 0.2070 - mean_absolute_error: 0.6141 - val_loss: 0.0860 - val_mean_absolute_error: 0.3150
# Epoch 27/250
# 1785/1785 [==============================] - 1s 711us/step - loss: 0.2070 - mean_absolute_error: 0.6140 - val_loss: 0.0860 - val_mean_absolute_error: 0.3150
# Epoch 28/250
# 1785/1785 [==============================] - 1s 658us/step - loss: 0.2070 - mean_absolute_error: 0.6140 - val_loss: 0.0860 - val_mean_absolute_error: 0.3150
# Epoch 29/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 0.2070 - mean_absolute_error: 0.6139 - val_loss: 0.0860 - val_mean_absolute_error: 0.3151
# Epoch 30/250
# 1785/1785 [==============================] - 1s 662us/step - loss: 0.2069 - mean_absolute_error: 0.6139 - val_loss: 0.0860 - val_mean_absolute_error: 0.3151
# Epoch 31/250
# 1785/1785 [==============================] - 1s 660us/step - loss: 0.2069 - mean_absolute_error: 0.6138 - val_loss: 0.0861 - val_mean_absolute_error: 0.3151
# Epoch 32/250
# 1785/1785 [==============================] - 1s 683us/step - loss: 0.2068 - mean_absolute_error: 0.6137 - val_loss: 0.0861 - val_mean_absolute_error: 0.3152
# Epoch 33/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 0.2068 - mean_absolute_error: 0.6136 - val_loss: 0.0861 - val_mean_absolute_error: 0.3152
# Epoch 34/250
# 1785/1785 [==============================] - 1s 698us/step - loss: 0.2067 - mean_absolute_error: 0.6135 - val_loss: 0.0861 - val_mean_absolute_error: 0.3153
# Epoch 35/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 0.2066 - mean_absolute_error: 0.6134 - val_loss: 0.0861 - val_mean_absolute_error: 0.3153
# Epoch 36/250
# 1785/1785 [==============================] - 1s 654us/step - loss: 0.2065 - mean_absolute_error: 0.6133 - val_loss: 0.0861 - val_mean_absolute_error: 0.3154
# Epoch 37/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 0.2065 - mean_absolute_error: 0.6131 - val_loss: 0.0862 - val_mean_absolute_error: 0.3154
# Epoch 38/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 0.2064 - mean_absolute_error: 0.6130 - val_loss: 0.0862 - val_mean_absolute_error: 0.3155
# Epoch 39/250
# 1785/1785 [==============================] - 1s 683us/step - loss: 0.2062 - mean_absolute_error: 0.6128 - val_loss: 0.0862 - val_mean_absolute_error: 0.3156
# Epoch 40/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 0.2061 - mean_absolute_error: 0.6126 - val_loss: 0.0863 - val_mean_absolute_error: 0.3157
# Epoch 41/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 0.2060 - mean_absolute_error: 0.6124 - val_loss: 0.0863 - val_mean_absolute_error: 0.3158
# Epoch 42/250
# 1785/1785 [==============================] - 1s 657us/step - loss: 0.2058 - mean_absolute_error: 0.6121 - val_loss: 0.0864 - val_mean_absolute_error: 0.3159
# Epoch 43/250
# 1785/1785 [==============================] - 1s 668us/step - loss: 0.2056 - mean_absolute_error: 0.6118 - val_loss: 0.0864 - val_mean_absolute_error: 0.3160
# Epoch 44/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 0.2054 - mean_absolute_error: 0.6115 - val_loss: 0.0865 - val_mean_absolute_error: 0.3162
# Epoch 45/250
# 1785/1785 [==============================] - 1s 674us/step - loss: 0.2052 - mean_absolute_error: 0.6111 - val_loss: 0.0865 - val_mean_absolute_error: 0.3164
# Epoch 46/250
# 1785/1785 [==============================] - 1s 664us/step - loss: 0.2050 - mean_absolute_error: 0.6107 - val_loss: 0.0866 - val_mean_absolute_error: 0.3166
# Epoch 47/250
# 1785/1785 [==============================] - 1s 698us/step - loss: 0.2047 - mean_absolute_error: 0.6103 - val_loss: 0.0867 - val_mean_absolute_error: 0.3168
# Epoch 48/250
# 1785/1785 [==============================] - 1s 687us/step - loss: 0.2044 - mean_absolute_error: 0.6098 - val_loss: 0.0868 - val_mean_absolute_error: 0.3170
# Epoch 49/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 0.2040 - mean_absolute_error: 0.6092 - val_loss: 0.0869 - val_mean_absolute_error: 0.3173
# Epoch 50/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 0.2036 - mean_absolute_error: 0.6086 - val_loss: 0.0870 - val_mean_absolute_error: 0.3176
# Epoch 51/250
# 1785/1785 [==============================] - 1s 724us/step - loss: 0.2032 - mean_absolute_error: 0.6079 - val_loss: 0.0871 - val_mean_absolute_error: 0.3179
# Epoch 52/250
# 1785/1785 [==============================] - 1s 666us/step - loss: 0.2027 - mean_absolute_error: 0.6071 - val_loss: 0.0872 - val_mean_absolute_error: 0.3183
# Epoch 53/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 0.2021 - mean_absolute_error: 0.6062 - val_loss: 0.0874 - val_mean_absolute_error: 0.3187
# Epoch 54/250
# 1785/1785 [==============================] - 1s 728us/step - loss: 0.2015 - mean_absolute_error: 0.6052 - val_loss: 0.0876 - val_mean_absolute_error: 0.3192
# Epoch 55/250
# 1785/1785 [==============================] - 1s 691us/step - loss: 0.2008 - mean_absolute_error: 0.6041 - val_loss: 0.0878 - val_mean_absolute_error: 0.3198
# Epoch 56/250
# 1785/1785 [==============================] - 1s 702us/step - loss: 0.2001 - mean_absolute_error: 0.6028 - val_loss: 0.0880 - val_mean_absolute_error: 0.3204
# Epoch 57/250
# 1785/1785 [==============================] - 1s 662us/step - loss: 0.1992 - mean_absolute_error: 0.6014 - val_loss: 0.0883 - val_mean_absolute_error: 0.3211
# Epoch 58/250
# 1785/1785 [==============================] - 1s 717us/step - loss: 0.1982 - mean_absolute_error: 0.5998 - val_loss: 0.0886 - val_mean_absolute_error: 0.3218
# Epoch 59/250
# 1785/1785 [==============================] - 1s 683us/step - loss: 0.1971 - mean_absolute_error: 0.5980 - val_loss: 0.0889 - val_mean_absolute_error: 0.3227
# Epoch 60/250
# 1785/1785 [==============================] - 1s 679us/step - loss: 0.1959 - mean_absolute_error: 0.5961 - val_loss: 0.0893 - val_mean_absolute_error: 0.3237
# Epoch 61/250
# 1785/1785 [==============================] - 1s 661us/step - loss: 0.1946 - mean_absolute_error: 0.5939 - val_loss: 0.0897 - val_mean_absolute_error: 0.3248
# Epoch 62/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 0.1931 - mean_absolute_error: 0.5914 - val_loss: 0.0901 - val_mean_absolute_error: 0.3260
# Epoch 63/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 0.1914 - mean_absolute_error: 0.5886 - val_loss: 0.0907 - val_mean_absolute_error: 0.3274
# Epoch 64/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 0.1896 - mean_absolute_error: 0.5855 - val_loss: 0.0912 - val_mean_absolute_error: 0.3290
# Epoch 65/250
# 1785/1785 [==============================] - 1s 664us/step - loss: 0.1876 - mean_absolute_error: 0.5821 - val_loss: 0.0919 - val_mean_absolute_error: 0.3308
# Epoch 66/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 0.1853 - mean_absolute_error: 0.5782 - val_loss: 0.0927 - val_mean_absolute_error: 0.3328
# Epoch 67/250
# 1785/1785 [==============================] - 1s 694us/step - loss: 0.1828 - mean_absolute_error: 0.5740 - val_loss: 0.0935 - val_mean_absolute_error: 0.3351
# Epoch 68/250
# 1785/1785 [==============================] - 1s 732us/step - loss: 0.1800 - mean_absolute_error: 0.5692 - val_loss: 0.0944 - val_mean_absolute_error: 0.3376
# Epoch 69/250
# 1785/1785 [==============================] - 1s 659us/step - loss: 0.1769 - mean_absolute_error: 0.5638 - val_loss: 0.0955 - val_mean_absolute_error: 0.3404
# Epoch 70/250
# 1785/1785 [==============================] - 1s 705us/step - loss: 0.1735 - mean_absolute_error: 0.5579 - val_loss: 0.0967 - val_mean_absolute_error: 0.3435
# Epoch 71/250
# 1785/1785 [==============================] - 1s 656us/step - loss: 0.1698 - mean_absolute_error: 0.5514 - val_loss: 0.0981 - val_mean_absolute_error: 0.3470
# Epoch 72/250
# 1785/1785 [==============================] - 1s 723us/step - loss: 0.1657 - mean_absolute_error: 0.5440 - val_loss: 0.0996 - val_mean_absolute_error: 0.3509
# Epoch 73/250
# 1785/1785 [==============================] - 1s 709us/step - loss: 0.1612 - mean_absolute_error: 0.5359 - val_loss: 0.1014 - val_mean_absolute_error: 0.3553
# Epoch 74/250
# 1785/1785 [==============================] - 1s 720us/step - loss: 0.1563 - mean_absolute_error: 0.5269 - val_loss: 0.1034 - val_mean_absolute_error: 0.3601
# Epoch 75/250
# 1785/1785 [==============================] - 1s 737us/step - loss: 0.1510 - mean_absolute_error: 0.5170 - val_loss: 0.1056 - val_mean_absolute_error: 0.3655
# Epoch 76/250
# 1785/1785 [==============================] - 1s 740us/step - loss: 0.1453 - mean_absolute_error: 0.5060 - val_loss: 0.1081 - val_mean_absolute_error: 0.3715
# Epoch 77/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 0.1392 - mean_absolute_error: 0.4939 - val_loss: 0.1110 - val_mean_absolute_error: 0.3784
# Epoch 78/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 0.1325 - mean_absolute_error: 0.4806 - val_loss: 0.1142 - val_mean_absolute_error: 0.3861
# Epoch 79/250
# 1785/1785 [==============================] - 1s 653us/step - loss: 0.1254 - mean_absolute_error: 0.4660 - val_loss: 0.1178 - val_mean_absolute_error: 0.3946
# Epoch 80/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 0.1179 - mean_absolute_error: 0.4501 - val_loss: 0.1218 - val_mean_absolute_error: 0.4041
# Epoch 81/250
# 1785/1785 [==============================] - 1s 690us/step - loss: 0.1101 - mean_absolute_error: 0.4327 - val_loss: 0.1264 - val_mean_absolute_error: 0.4145
# Epoch 82/250
# 1785/1785 [==============================] - 1s 703us/step - loss: 0.1019 - mean_absolute_error: 0.4138 - val_loss: 0.1315 - val_mean_absolute_error: 0.4264
# Epoch 83/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 0.0934 - mean_absolute_error: 0.3934 - val_loss: 0.1372 - val_mean_absolute_error: 0.4402
# Epoch 84/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 0.0846 - mean_absolute_error: 0.3717 - val_loss: 0.1434 - val_mean_absolute_error: 0.4558
# Epoch 85/250
# 1785/1785 [==============================] - 1s 661us/step - loss: 0.0759 - mean_absolute_error: 0.3490 - val_loss: 0.1504 - val_mean_absolute_error: 0.4725
# Epoch 86/250
# 1785/1785 [==============================] - 1s 660us/step - loss: 0.0672 - mean_absolute_error: 0.3253 - val_loss: 0.1580 - val_mean_absolute_error: 0.4901
# Epoch 87/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 0.0586 - mean_absolute_error: 0.3011 - val_loss: 0.1663 - val_mean_absolute_error: 0.5085
# Epoch 88/250
# 1785/1785 [==============================] - 1s 661us/step - loss: 0.0504 - mean_absolute_error: 0.2773 - val_loss: 0.1752 - val_mean_absolute_error: 0.5276
# Epoch 89/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 0.0427 - mean_absolute_error: 0.2537 - val_loss: 0.1846 - val_mean_absolute_error: 0.5471
# Epoch 90/250
# 1785/1785 [==============================] - 1s 684us/step - loss: 0.0356 - mean_absolute_error: 0.2306 - val_loss: 0.1944 - val_mean_absolute_error: 0.5666
# Epoch 91/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 0.0294 - mean_absolute_error: 0.2083 - val_loss: 0.2045 - val_mean_absolute_error: 0.5859
# Epoch 92/250
# 1785/1785 [==============================] - 1s 694us/step - loss: 0.0241 - mean_absolute_error: 0.1875 - val_loss: 0.2144 - val_mean_absolute_error: 0.6046
# Epoch 93/250
# 1785/1785 [==============================] - 1s 709us/step - loss: 0.0198 - mean_absolute_error: 0.1685 - val_loss: 0.2240 - val_mean_absolute_error: 0.6221
# Epoch 94/250
# 1785/1785 [==============================] - 1s 688us/step - loss: 0.0166 - mean_absolute_error: 0.1516 - val_loss: 0.2329 - val_mean_absolute_error: 0.6378
# Epoch 95/250
# 1785/1785 [==============================] - 1s 668us/step - loss: 0.0142 - mean_absolute_error: 0.1382 - val_loss: 0.2405 - val_mean_absolute_error: 0.6512
# Epoch 96/250
# 1785/1785 [==============================] - 1s 661us/step - loss: 0.0127 - mean_absolute_error: 0.1285 - val_loss: 0.2467 - val_mean_absolute_error: 0.6621
# Epoch 97/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 0.0118 - mean_absolute_error: 0.1230 - val_loss: 0.2510 - val_mean_absolute_error: 0.6696
# Epoch 98/250
# 1785/1785 [==============================] - 1s 677us/step - loss: 0.0114 - mean_absolute_error: 0.1204 - val_loss: 0.2534 - val_mean_absolute_error: 0.6741
# Epoch 99/250
# 1785/1785 [==============================] - 1s 659us/step - loss: 0.0111 - mean_absolute_error: 0.1191 - val_loss: 0.2538 - val_mean_absolute_error: 0.6754
# Epoch 100/250
# 1785/1785 [==============================] - 1s 692us/step - loss: 0.0110 - mean_absolute_error: 0.1184 - val_loss: 0.2523 - val_mean_absolute_error: 0.6737
# Epoch 101/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 0.0109 - mean_absolute_error: 0.1178 - val_loss: 0.2493 - val_mean_absolute_error: 0.6698
# Epoch 102/250
# 1785/1785 [==============================] - 1s 676us/step - loss: 0.0107 - mean_absolute_error: 0.1171 - val_loss: 0.2452 - val_mean_absolute_error: 0.6641
# Epoch 103/250
# 1785/1785 [==============================] - 1s 666us/step - loss: 0.0106 - mean_absolute_error: 0.1161 - val_loss: 0.2401 - val_mean_absolute_error: 0.6568
# Epoch 104/250
# 1785/1785 [==============================] - 1s 669us/step - loss: 0.0104 - mean_absolute_error: 0.1150 - val_loss: 0.2341 - val_mean_absolute_error: 0.6481
# Epoch 105/250
# 1785/1785 [==============================] - 1s 658us/step - loss: 0.0102 - mean_absolute_error: 0.1138 - val_loss: 0.2284 - val_mean_absolute_error: 0.6398
# Epoch 106/250
# 1785/1785 [==============================] - 1s 690us/step - loss: 0.0099 - mean_absolute_error: 0.1125 - val_loss: 0.2219 - val_mean_absolute_error: 0.6305
# Epoch 107/250
# 1785/1785 [==============================] - 1s 689us/step - loss: 0.0097 - mean_absolute_error: 0.1111 - val_loss: 0.2151 - val_mean_absolute_error: 0.6206
# Epoch 108/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 0.0094 - mean_absolute_error: 0.1095 - val_loss: 0.2080 - val_mean_absolute_error: 0.6103
# Epoch 109/250
# 1785/1785 [==============================] - 1s 706us/step - loss: 0.0091 - mean_absolute_error: 0.1076 - val_loss: 0.1993 - val_mean_absolute_error: 0.5971
# Epoch 110/250
# 1785/1785 [==============================] - 1s 676us/step - loss: 0.0087 - mean_absolute_error: 0.1055 - val_loss: 0.1888 - val_mean_absolute_error: 0.5808
# Epoch 111/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 0.0083 - mean_absolute_error: 0.1031 - val_loss: 0.1784 - val_mean_absolute_error: 0.5645
# Epoch 112/250
# 1785/1785 [==============================] - 1s 672us/step - loss: 0.0079 - mean_absolute_error: 0.1004 - val_loss: 0.1669 - val_mean_absolute_error: 0.5457
# Epoch 113/250
# 1785/1785 [==============================] - 1s 688us/step - loss: 0.0074 - mean_absolute_error: 0.0974 - val_loss: 0.1543 - val_mean_absolute_error: 0.5245
# Epoch 114/250
# 1785/1785 [==============================] - 1s 732us/step - loss: 0.0069 - mean_absolute_error: 0.0940 - val_loss: 0.1408 - val_mean_absolute_error: 0.5005
# Epoch 115/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 0.0063 - mean_absolute_error: 0.0902 - val_loss: 0.1257 - val_mean_absolute_error: 0.4724
# Epoch 116/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 0.0057 - mean_absolute_error: 0.0860 - val_loss: 0.1103 - val_mean_absolute_error: 0.4418
# Epoch 117/250
# 1785/1785 [==============================] - 1s 683us/step - loss: 0.0051 - mean_absolute_error: 0.0809 - val_loss: 0.0932 - val_mean_absolute_error: 0.4047
# Epoch 118/250
# 1785/1785 [==============================] - 1s 659us/step - loss: 0.0044 - mean_absolute_error: 0.0754 - val_loss: 0.0773 - val_mean_absolute_error: 0.3677
# Epoch 119/250
# 1785/1785 [==============================] - 1s 668us/step - loss: 0.0037 - mean_absolute_error: 0.0692 - val_loss: 0.0603 - val_mean_absolute_error: 0.3222
# Epoch 120/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 0.0030 - mean_absolute_error: 0.0623 - val_loss: 0.0449 - val_mean_absolute_error: 0.2754
# Epoch 121/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 0.0023 - mean_absolute_error: 0.0550 - val_loss: 0.0305 - val_mean_absolute_error: 0.2224
# Epoch 122/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 0.0017 - mean_absolute_error: 0.0471 - val_loss: 0.0190 - val_mean_absolute_error: 0.1708
# Epoch 123/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 0.0012 - mean_absolute_error: 0.0390 - val_loss: 0.0105 - val_mean_absolute_error: 0.1189
# Epoch 124/250
# 1785/1785 [==============================] - 1s 672us/step - loss: 7.8683e-04 - mean_absolute_error: 0.0315 - val_loss: 0.0054 - val_mean_absolute_error: 0.0773
# Epoch 125/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 5.4496e-04 - mean_absolute_error: 0.0259 - val_loss: 0.0033 - val_mean_absolute_error: 0.0578
# Epoch 126/250
# 1785/1785 [==============================] - 1s 672us/step - loss: 4.2798e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0032 - val_mean_absolute_error: 0.0606
# Epoch 127/250
# 1785/1785 [==============================] - 1s 694us/step - loss: 3.9142e-04 - mean_absolute_error: 0.0217 - val_loss: 0.0037 - val_mean_absolute_error: 0.0689
# Epoch 128/250
# 1785/1785 [==============================] - 1s 668us/step - loss: 3.8866e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0041 - val_mean_absolute_error: 0.0733
# Epoch 129/250
# 1785/1785 [==============================] - 1s 689us/step - loss: 3.9042e-04 - mean_absolute_error: 0.0215 - val_loss: 0.0041 - val_mean_absolute_error: 0.0735
# Epoch 130/250
# 1785/1785 [==============================] - 1s 706us/step - loss: 3.8776e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0037 - val_mean_absolute_error: 0.0691
# Epoch 131/250
# 1785/1785 [==============================] - 1s 679us/step - loss: 3.8303e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0035 - val_mean_absolute_error: 0.0656
# Epoch 132/250
# 1785/1785 [==============================] - 1s 677us/step - loss: 3.8082e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0033 - val_mean_absolute_error: 0.0635
# Epoch 133/250
# 1785/1785 [==============================] - 1s 701us/step - loss: 3.8691e-04 - mean_absolute_error: 0.0215 - val_loss: 0.0033 - val_mean_absolute_error: 0.0631
# Epoch 134/250
# 1785/1785 [==============================] - 1s 760us/step - loss: 3.7957e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0033 - val_mean_absolute_error: 0.0627
# Epoch 135/250
# 1785/1785 [==============================] - 1s 722us/step - loss: 3.7565e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0033 - val_mean_absolute_error: 0.0631
# Epoch 136/250
# 1785/1785 [==============================] - 1s 714us/step - loss: 3.7644e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0032 - val_mean_absolute_error: 0.0622
# Epoch 137/250
# 1785/1785 [==============================] - 1s 689us/step - loss: 3.6980e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0032 - val_mean_absolute_error: 0.0606
# Epoch 138/250
# 1785/1785 [==============================] - 1s 689us/step - loss: 3.6540e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0031 - val_mean_absolute_error: 0.0598
# Epoch 139/250
# 1785/1785 [==============================] - 1s 661us/step - loss: 3.6130e-04 - mean_absolute_error: 0.0207 - val_loss: 0.0031 - val_mean_absolute_error: 0.0591
# Epoch 140/250
# 1785/1785 [==============================] - 1s 677us/step - loss: 3.6194e-04 - mean_absolute_error: 0.0207 - val_loss: 0.0031 - val_mean_absolute_error: 0.0588
# Epoch 141/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 3.5595e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0031 - val_mean_absolute_error: 0.0576
# Epoch 142/250
# 1785/1785 [==============================] - 1s 695us/step - loss: 3.6848e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0031 - val_mean_absolute_error: 0.0578
# Epoch 143/250
# 1785/1785 [==============================] - 1s 710us/step - loss: 3.6252e-04 - mean_absolute_error: 0.0207 - val_loss: 0.0030 - val_mean_absolute_error: 0.0568
# Epoch 144/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 3.5099e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0031 - val_mean_absolute_error: 0.0565
# Epoch 145/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 3.5431e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0030 - val_mean_absolute_error: 0.0555
# Epoch 146/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 3.7215e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0032 - val_mean_absolute_error: 0.0573
# Epoch 147/250
# 1785/1785 [==============================] - 1s 656us/step - loss: 3.5075e-04 - mean_absolute_error: 0.0203 - val_loss: 0.0032 - val_mean_absolute_error: 0.0577
# Epoch 148/250
# 1785/1785 [==============================] - 1s 699us/step - loss: 3.6083e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0034 - val_mean_absolute_error: 0.0576
# Epoch 149/250
# 1785/1785 [==============================] - 1s 669us/step - loss: 3.2951e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0034 - val_mean_absolute_error: 0.0591
# Epoch 150/250
# 1785/1785 [==============================] - 1s 713us/step - loss: 0.0666 - mean_absolute_error: 0.2759 - val_loss: 0.6126 - val_mean_absolute_error: 1.1039
# Epoch 151/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 0.0382 - mean_absolute_error: 0.2268 - val_loss: 0.2301 - val_mean_absolute_error: 0.6168
# Epoch 152/250
# 1785/1785 [==============================] - 1s 683us/step - loss: 0.0239 - mean_absolute_error: 0.1788 - val_loss: 0.1928 - val_mean_absolute_error: 0.5779
# Epoch 153/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 0.0088 - mean_absolute_error: 0.1088 - val_loss: 0.0203 - val_mean_absolute_error: 0.1330
# Epoch 154/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 0.0031 - mean_absolute_error: 0.0652 - val_loss: 0.0761 - val_mean_absolute_error: 0.3300
# Epoch 155/250
# 1785/1785 [==============================] - 1s 680us/step - loss: 0.0020 - mean_absolute_error: 0.0515 - val_loss: 0.0570 - val_mean_absolute_error: 0.2529
# Epoch 156/250
# 1785/1785 [==============================] - 1s 681us/step - loss: 7.6101e-04 - mean_absolute_error: 0.0311 - val_loss: 0.0594 - val_mean_absolute_error: 0.2579
# Epoch 157/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 4.7494e-04 - mean_absolute_error: 0.0240 - val_loss: 0.0741 - val_mean_absolute_error: 0.3043
# Epoch 158/250
# 1785/1785 [==============================] - 1s 697us/step - loss: 6.2219e-04 - mean_absolute_error: 0.0289 - val_loss: 0.0842 - val_mean_absolute_error: 0.3339
# Epoch 159/250
# 1785/1785 [==============================] - 1s 759us/step - loss: 5.4128e-04 - mean_absolute_error: 0.0264 - val_loss: 0.0849 - val_mean_absolute_error: 0.3358
# Epoch 160/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 4.5601e-04 - mean_absolute_error: 0.0236 - val_loss: 0.0707 - val_mean_absolute_error: 0.2946
# Epoch 161/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 5.1710e-04 - mean_absolute_error: 0.0257 - val_loss: 0.0719 - val_mean_absolute_error: 0.3014
# Epoch 162/250
# 1785/1785 [==============================] - 1s 668us/step - loss: 0.0010 - mean_absolute_error: 0.0387 - val_loss: 0.0844 - val_mean_absolute_error: 0.3409
# Epoch 163/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 0.0016 - mean_absolute_error: 0.0479 - val_loss: 0.1071 - val_mean_absolute_error: 0.3967
# Epoch 164/250
# 1785/1785 [==============================] - 1s 695us/step - loss: 0.0033 - mean_absolute_error: 0.0665 - val_loss: 0.0678 - val_mean_absolute_error: 0.2786
# Epoch 165/250
# 1785/1785 [==============================] - 1s 668us/step - loss: 0.4518 - mean_absolute_error: 0.7678 - val_loss: 18.6560 - val_mean_absolute_error: 19.1560
# Epoch 166/250
# 1785/1785 [==============================] - 1s 674us/step - loss: 31.4563 - mean_absolute_error: 31.9563 - val_loss: 36.6081 - val_mean_absolute_error: 37.1081
# Epoch 167/250
# 1785/1785 [==============================] - 1s 722us/step - loss: 33.6569 - mean_absolute_error: 34.1569 - val_loss: 39.4866 - val_mean_absolute_error: 39.9866
# Epoch 168/250
# 1785/1785 [==============================] - 1s 766us/step - loss: 35.8985 - mean_absolute_error: 36.3985 - val_loss: 70.9816 - val_mean_absolute_error: 71.4816
# Epoch 169/250
# 1785/1785 [==============================] - 1s 707us/step - loss: 45.0068 - mean_absolute_error: 45.5068 - val_loss: 41.1465 - val_mean_absolute_error: 41.6465
# Epoch 170/250
# 1785/1785 [==============================] - 1s 703us/step - loss: 44.5908 - mean_absolute_error: 45.0908 - val_loss: 90.4969 - val_mean_absolute_error: 90.9969
# Epoch 171/250
# 1785/1785 [==============================] - 1s 730us/step - loss: 56.6885 - mean_absolute_error: 57.1885 - val_loss: 54.5996 - val_mean_absolute_error: 55.0996
# Epoch 172/250
# 1785/1785 [==============================] - 1s 693us/step - loss: 56.7750 - mean_absolute_error: 57.2750 - val_loss: 109.6297 - val_mean_absolute_error: 110.1297
# Epoch 173/250
# 1785/1785 [==============================] - 1s 684us/step - loss: 70.7909 - mean_absolute_error: 71.2909 - val_loss: 74.1370 - val_mean_absolute_error: 74.6370
# Epoch 174/250
# 1785/1785 [==============================] - 1s 705us/step - loss: 72.3903 - mean_absolute_error: 72.8903 - val_loss: 132.4615 - val_mean_absolute_error: 132.9615
# Epoch 175/250
# 1785/1785 [==============================] - 1s 689us/step - loss: 88.4080 - mean_absolute_error: 88.9080 - val_loss: 99.3452 - val_mean_absolute_error: 99.8452
# Epoch 176/250
# 1785/1785 [==============================] - 1s 677us/step - loss: 92.1080 - mean_absolute_error: 92.6080 - val_loss: 160.9172 - val_mean_absolute_error: 161.4172
# Epoch 177/250
# 1785/1785 [==============================] - 1s 692us/step - loss: 110.5753 - mean_absolute_error: 111.0753 - val_loss: 131.2195 - val_mean_absolute_error: 131.7195
# Epoch 178/250
# 1785/1785 [==============================] - 1s 682us/step - loss: 116.9617 - mean_absolute_error: 117.4617 - val_loss: 196.6742 - val_mean_absolute_error: 197.1742
# Epoch 179/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 138.4590 - mean_absolute_error: 138.9590 - val_loss: 171.3563 - val_mean_absolute_error: 171.8563
# Epoch 180/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 148.2665 - mean_absolute_error: 148.7665 - val_loss: 241.6999 - val_mean_absolute_error: 242.2000
# Epoch 181/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 173.5503 - mean_absolute_error: 174.0503 - val_loss: 221.8802 - val_mean_absolute_error: 222.3802
# Epoch 182/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 187.6513 - mean_absolute_error: 188.1513 - val_loss: 298.3866 - val_mean_absolute_error: 298.8866
# Epoch 183/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 217.7563 - mean_absolute_error: 218.2563 - val_loss: 285.4842 - val_mean_absolute_error: 285.9842
# Epoch 184/250
# 1785/1785 [==============================] - 1s 708us/step - loss: 237.2268 - mean_absolute_error: 237.7268 - val_loss: 369.7537 - val_mean_absolute_error: 370.2537
# Epoch 185/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 273.3991 - mean_absolute_error: 273.8991 - val_loss: 365.5531 - val_mean_absolute_error: 366.0531
# Epoch 186/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 299.6629 - mean_absolute_error: 300.1629 - val_loss: 459.6029 - val_mean_absolute_error: 460.1029
# Epoch 187/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 343.4401 - mean_absolute_error: 343.9401 - val_loss: 466.3497 - val_mean_absolute_error: 466.8497
# Epoch 188/250
# 1785/1785 [==============================] - 1s 689us/step - loss: 378.2583 - mean_absolute_error: 378.7583 - val_loss: 572.7203 - val_mean_absolute_error: 573.2203
# Epoch 189/250
# 1785/1785 [==============================] - 1s 714us/step - loss: 431.6252 - mean_absolute_error: 432.1252 - val_loss: 593.2424 - val_mean_absolute_error: 593.7424
# Epoch 190/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 477.1969 - mean_absolute_error: 477.6970 - val_loss: 715.1310 - val_mean_absolute_error: 715.6309
# Epoch 191/250
# 1785/1785 [==============================] - 1s 692us/step - loss: 542.6422 - mean_absolute_error: 543.1422 - val_loss: 752.9890 - val_mean_absolute_error: 753.4890
# Epoch 192/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 601.7479 - mean_absolute_error: 602.2479 - val_loss: 894.4303 - val_mean_absolute_error: 894.9302
# Epoch 193/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 682.4156 - mean_absolute_error: 682.9156 - val_loss: 954.0707 - val_mean_absolute_error: 954.5707
# Epoch 194/250
# 1785/1785 [==============================] - 1s 654us/step - loss: 764.5742 - mean_absolute_error: 765.0742 - val_loss: 997.2626 - val_mean_absolute_error: 997.7627
# Epoch 195/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 830.4865 - mean_absolute_error: 830.9865 - val_loss: 1516.9515 - val_mean_absolute_error: 1517.4515
# Epoch 196/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 1004.3093 - mean_absolute_error: 1004.8094 - val_loss: 1005.2257 - val_mean_absolute_error: 1005.7257
# Epoch 197/250
# 1785/1785 [==============================] - 1s 741us/step - loss: 1021.7496 - mean_absolute_error: 1022.2496 - val_loss: 1967.8096 - val_mean_absolute_error: 1968.3094
# Epoch 198/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 1267.3035 - mean_absolute_error: 1267.8034 - val_loss: 1299.7232 - val_mean_absolute_error: 1300.2232
# Epoch 199/250
# 1785/1785 [==============================] - 1s 674us/step - loss: 1293.6865 - mean_absolute_error: 1294.1866 - val_loss: 2399.3414 - val_mean_absolute_error: 2399.8414
# Epoch 200/250
# 1785/1785 [==============================] - 1s 666us/step - loss: 1583.5021 - mean_absolute_error: 1584.0020 - val_loss: 1735.5518 - val_mean_absolute_error: 1736.0519
# Epoch 201/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 1643.1719 - mean_absolute_error: 1643.6719 - val_loss: 2911.4833 - val_mean_absolute_error: 2911.9831
# Epoch 202/250
# 1785/1785 [==============================] - 1s 703us/step - loss: 1978.1610 - mean_absolute_error: 1978.6610 - val_loss: 2299.1176 - val_mean_absolute_error: 2299.6176
# Epoch 203/250
# 1785/1785 [==============================] - 1s 692us/step - loss: 2084.7758 - mean_absolute_error: 2085.2758 - val_loss: 3549.1047 - val_mean_absolute_error: 3549.6047
# Epoch 204/250
# 1785/1785 [==============================] - 1s 689us/step - loss: 2474.2168 - mean_absolute_error: 2474.7169 - val_loss: 3012.0177 - val_mean_absolute_error: 3012.5179
# Epoch 205/250
# 1785/1785 [==============================] - 1s 698us/step - loss: 2641.0732 - mean_absolute_error: 2641.5732 - val_loss: 4350.1926 - val_mean_absolute_error: 4350.6926
# Epoch 206/250
# 1785/1785 [==============================] - 1s 681us/step - loss: 3098.5451 - mean_absolute_error: 3099.0450 - val_loss: 3910.2777 - val_mean_absolute_error: 3910.7777
# Epoch 207/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 3341.5168 - mean_absolute_error: 3342.0166 - val_loss: 5358.3370 - val_mean_absolute_error: 5358.8370
# Epoch 208/250
# 1785/1785 [==============================] - 1s 664us/step - loss: 3884.4820 - mean_absolute_error: 3884.9820 - val_loss: 5041.2930 - val_mean_absolute_error: 5041.7930
# Epoch 209/250
# 1785/1785 [==============================] - 1s 674us/step - loss: 4223.3428 - mean_absolute_error: 4223.8428 - val_loss: 6627.4295 - val_mean_absolute_error: 6627.9290
# Epoch 210/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 4873.9153 - mean_absolute_error: 4874.4152 - val_loss: 6465.2039 - val_mean_absolute_error: 6465.7039
# Epoch 211/250
# 1785/1785 [==============================] - 1s 660us/step - loss: 5333.4964 - mean_absolute_error: 5333.9963 - val_loss: 8225.0994 - val_mean_absolute_error: 8225.5994
# Epoch 212/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 6119.5330 - mean_absolute_error: 6120.0329 - val_loss: 8257.8123 - val_mean_absolute_error: 8258.3128
# Epoch 213/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 6731.1020 - mean_absolute_error: 6731.6020 - val_loss: 10236.4451 - val_mean_absolute_error: 10236.9446
# Epoch 214/250
# 1785/1785 [==============================] - 1s 672us/step - loss: 7687.6637 - mean_absolute_error: 7688.1637 - val_loss: 10514.5687 - val_mean_absolute_error: 10515.0687
# Epoch 215/250
# 1785/1785 [==============================] - 1s 686us/step - loss: 8490.5760 - mean_absolute_error: 8491.0762 - val_loss: 12768.5766 - val_mean_absolute_error: 12769.0760
# Epoch 216/250
# 1785/1785 [==============================] - 1s 686us/step - loss: 9661.8405 - mean_absolute_error: 9662.3407 - val_loss: 13355.6538 - val_mean_absolute_error: 13356.1542
# Epoch 217/250
# 1785/1785 [==============================] - 1s 653us/step - loss: 10705.6279 - mean_absolute_error: 10706.1280 - val_loss: 15956.3514 - val_mean_absolute_error: 15956.8508
# Epoch 218/250
# 1785/1785 [==============================] - 1s 644us/step - loss: 12147.1737 - mean_absolute_error: 12147.6741 - val_loss: 16932.3812 - val_mean_absolute_error: 16932.8812
# Epoch 219/250
# 1785/1785 [==============================] - 1s 741us/step - loss: 13494.2126 - mean_absolute_error: 13494.7122 - val_loss: 19969.4852 - val_mean_absolute_error: 19969.9852
# Epoch 220/250
# 1785/1785 [==============================] - 1s 701us/step - loss: 15276.0084 - mean_absolute_error: 15276.5079 - val_loss: 21435.2336 - val_mean_absolute_error: 21435.7344
# Epoch 221/250
# 1785/1785 [==============================] - 1s 714us/step - loss: 17004.8392 - mean_absolute_error: 17005.3393 - val_loss: 25021.7458 - val_mean_absolute_error: 25022.2469
# Epoch 222/250
# 1785/1785 [==============================] - 1s 655us/step - loss: 19214.9834 - mean_absolute_error: 19215.4827 - val_loss: 27103.9509 - val_mean_absolute_error: 27104.4512
# Epoch 223/250
# 1785/1785 [==============================] - 1s 655us/step - loss: 21424.4369 - mean_absolute_error: 21424.9369 - val_loss: 31382.2017 - val_mean_absolute_error: 31382.7023
# Epoch 224/250
# 1785/1785 [==============================] - 1s 700us/step - loss: 24173.8761 - mean_absolute_error: 24174.3761 - val_loss: 34240.4007 - val_mean_absolute_error: 34240.9007
# Epoch 225/250
# 1785/1785 [==============================] - 1s 668us/step - loss: 26988.3888 - mean_absolute_error: 26988.8882 - val_loss: 39389.5273 - val_mean_absolute_error: 39390.0290
# Epoch 226/250
# 1785/1785 [==============================] - 1s 679us/step - loss: 30416.7359 - mean_absolute_error: 30417.2364 - val_loss: 43224.7266 - val_mean_absolute_error: 43225.2266
# Epoch 227/250
# 1785/1785 [==============================] - 1s 694us/step - loss: 33993.0095 - mean_absolute_error: 33993.5095 - val_loss: 49470.0960 - val_mean_absolute_error: 49470.5954
# Epoch 228/250
# 1785/1785 [==============================] - 1s 677us/step - loss: 38276.0348 - mean_absolute_error: 38276.5353 - val_loss: 54535.3360 - val_mean_absolute_error: 54535.8343
# Epoch 229/250
# 1785/1785 [==============================] - 1s 693us/step - loss: 42811.2820 - mean_absolute_error: 42811.7823 - val_loss: 62160.8141 - val_mean_absolute_error: 62161.3102
# Epoch 230/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 48170.3068 - mean_absolute_error: 48170.8051 - val_loss: 68774.5609 - val_mean_absolute_error: 68775.0609
# Epoch 231/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 53912.8336 - mean_absolute_error: 53913.3347 - val_loss: 78137.5173 - val_mean_absolute_error: 78138.0173
# Epoch 232/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 60626.4643 - mean_absolute_error: 60626.9671 - val_loss: 86700.5642 - val_mean_absolute_error: 86701.0687
# Epoch 233/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 67888.8454 - mean_absolute_error: 67889.3487 - val_loss: 98250.9916 - val_mean_absolute_error: 98251.4905
# Epoch 234/250
# 1785/1785 [==============================] - 1s 714us/step - loss: 76307.8339 - mean_absolute_error: 76308.3373 - val_loss: 109268.1111 - val_mean_absolute_error: 109268.6077
# Epoch 235/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 85483.6076 - mean_absolute_error: 85484.1098 - val_loss: 123572.4548 - val_mean_absolute_error: 123572.9514
# Epoch 236/250
# 1785/1785 [==============================] - 1s 680us/step - loss: 96049.5322 - mean_absolute_error: 96050.0327 - val_loss: 137678.8220 - val_mean_absolute_error: 137679.3310
# Epoch 237/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 107634.0919 - mean_absolute_error: 107634.5952 - val_loss: 155450.1401 - val_mean_absolute_error: 155450.6467
# Epoch 238/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 120902.8135 - mean_absolute_error: 120903.3169 - val_loss: 173446.1658 - val_mean_absolute_error: 173446.6568
# Epoch 239/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 135519.9509 - mean_absolute_error: 135520.4453 - val_loss: 195581.5842 - val_mean_absolute_error: 195582.0932
# Epoch 240/250
# 1785/1785 [==============================] - 1s 677us/step - loss: 152191.2290 - mean_absolute_error: 152191.7334 - val_loss: 218474.7751 - val_mean_absolute_error: 218475.2662
# Epoch 241/250
# 1785/1785 [==============================] - 1s 669us/step - loss: 170626.2104 - mean_absolute_error: 170626.7126 - val_loss: 246103.7070 - val_mean_absolute_error: 246104.1936
# Epoch 242/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 191580.9629 - mean_absolute_error: 191581.4574 - val_loss: 275162.4381 - val_mean_absolute_error: 275162.9381
# Epoch 243/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 214822.3233 - mean_absolute_error: 214822.8210 - val_loss: 309707.7449 - val_mean_absolute_error: 309708.2628
# Epoch 244/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 241169.7518 - mean_absolute_error: 241170.2540 - val_loss: 346527.6747 - val_mean_absolute_error: 346528.1747
# Epoch 245/250
# 1785/1785 [==============================] - 1s 697us/step - loss: 270461.9090 - mean_absolute_error: 270462.4023 - val_loss: 389780.7449 - val_mean_absolute_error: 389781.2628
# Epoch 246/250
# 1785/1785 [==============================] - 1s 672us/step - loss: 303598.4232 - mean_absolute_error: 303598.9210 - val_loss: 436370.9918 - val_mean_absolute_error: 436371.4872
# Epoch 247/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 340507.9744 - mean_absolute_error: 340508.4878 - val_loss: 490586.4190 - val_mean_absolute_error: 490586.9011
# Epoch 248/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 382191.3444 - mean_absolute_error: 382191.8445 - val_loss: 549477.3221 - val_mean_absolute_error: 549477.8489
# Epoch 249/250
# 1785/1785 [==============================] - 1s 679us/step - loss: 428690.8594 - mean_absolute_error: 428691.3550 - val_loss: 617492.9994 - val_mean_absolute_error: 617493.4994
# Epoch 250/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 481133.9669 - mean_absolute_error: 481134.4848 - val_loss: 691870.3489 - val_mean_absolute_error: 691870.8489

# %% [markdown]
# Let's plot the loss for the testing data versus the learning rate.  We can see that it explodes past a learning rate of 1, so let's focus our window to before this point.

# %%
plt.semilogx(history.history['lr'], history.history['val_loss'])
plt.legend(['Learning Rate', 'Validation Loss'])

# %%
plt.semilogx(history.history['lr'][:140], history.history['loss'][:140])

# %% [markdown]
# It looks like the learning rate of 0.1 seems to work the best.  Let's use that learning rate and train the network this time for real.  Once we train the network, let's predict the prices for the training and test data.

# %%
# Observing the above graph, 0.1 seems to be the best learning rate
keras_model = Sequential([
  Conv1D(filters=128, kernel_size=5, input_shape=(window_size, 1), strides=1, padding="causal", activation="tanh"),
  Conv1D(filters=128, kernel_size=5, strides=1, padding="causal", activation="tanh"),
  LSTM(128, return_sequences=True),
  LSTM(128),
  Dense(64, activation="tanh"),
  Dense(64, activation="tanh"),
  Dense(1)
])


optimizer = SGD(lr=0.1, momentum=0.9)
keras_model.compile(loss=Huber(),
                    optimizer=optimizer,
                    metrics=["mae"])
history = keras_model.fit(X_train_reshape, y_train_reshape, batch_size=256, epochs=250, validation_data=(X_test_reshape, y_test_reshape))
# Out:
# Train on 1785 samples, validate on 447 samples
# Epoch 1/250
# 1785/1785 [==============================] - 3s 2ms/step - loss: 0.0751 - mean_absolute_error: 0.3277 - val_loss: 0.2441 - val_mean_absolute_error: 0.6412
# Epoch 2/250
# 1785/1785 [==============================] - 1s 705us/step - loss: 0.0286 - mean_absolute_error: 0.1939 - val_loss: 0.2927 - val_mean_absolute_error: 0.7137
# Epoch 3/250
# 1785/1785 [==============================] - 1s 701us/step - loss: 0.0251 - mean_absolute_error: 0.1863 - val_loss: 0.4551 - val_mean_absolute_error: 0.9306
# Epoch 4/250
# 1785/1785 [==============================] - 1s 746us/step - loss: 0.0179 - mean_absolute_error: 0.1536 - val_loss: 0.2801 - val_mean_absolute_error: 0.7028
# Epoch 5/250
# 1785/1785 [==============================] - 1s 710us/step - loss: 0.0133 - mean_absolute_error: 0.1323 - val_loss: 0.2292 - val_mean_absolute_error: 0.6394
# Epoch 6/250
# 1785/1785 [==============================] - 1s 737us/step - loss: 0.0068 - mean_absolute_error: 0.0934 - val_loss: 0.0674 - val_mean_absolute_error: 0.3332
# Epoch 7/250
# 1785/1785 [==============================] - 1s 709us/step - loss: 0.0017 - mean_absolute_error: 0.0472 - val_loss: 0.0082 - val_mean_absolute_error: 0.1083
# Epoch 8/250
# 1785/1785 [==============================] - 1s 725us/step - loss: 0.0018 - mean_absolute_error: 0.0473 - val_loss: 0.0082 - val_mean_absolute_error: 0.1090
# Epoch 9/250
# 1785/1785 [==============================] - 1s 730us/step - loss: 8.3585e-04 - mean_absolute_error: 0.0324 - val_loss: 0.0161 - val_mean_absolute_error: 0.1274
# Epoch 10/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 7.3719e-04 - mean_absolute_error: 0.0302 - val_loss: 0.0185 - val_mean_absolute_error: 0.1404
# Epoch 11/250
# 1785/1785 [==============================] - 1s 680us/step - loss: 5.4321e-04 - mean_absolute_error: 0.0259 - val_loss: 0.0109 - val_mean_absolute_error: 0.0964
# Epoch 12/250
# 1785/1785 [==============================] - 1s 682us/step - loss: 4.6327e-04 - mean_absolute_error: 0.0237 - val_loss: 0.0088 - val_mean_absolute_error: 0.0901
# Epoch 13/250
# 1785/1785 [==============================] - 1s 676us/step - loss: 4.6064e-04 - mean_absolute_error: 0.0238 - val_loss: 0.0106 - val_mean_absolute_error: 0.0950
# Epoch 14/250
# 1785/1785 [==============================] - 1s 683us/step - loss: 4.0418e-04 - mean_absolute_error: 0.0219 - val_loss: 0.0128 - val_mean_absolute_error: 0.1063
# Epoch 15/250
# 1785/1785 [==============================] - 1s 677us/step - loss: 3.8488e-04 - mean_absolute_error: 0.0215 - val_loss: 0.0127 - val_mean_absolute_error: 0.1058
# Epoch 16/250
# 1785/1785 [==============================] - 1s 696us/step - loss: 3.6665e-04 - mean_absolute_error: 0.0209 - val_loss: 0.0117 - val_mean_absolute_error: 0.1003
# Epoch 17/250
# 1785/1785 [==============================] - 1s 669us/step - loss: 3.6025e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0120 - val_mean_absolute_error: 0.1021
# Epoch 18/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 3.6141e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0125 - val_mean_absolute_error: 0.1052
# Epoch 19/250
# 1785/1785 [==============================] - 1s 688us/step - loss: 3.4826e-04 - mean_absolute_error: 0.0203 - val_loss: 0.0130 - val_mean_absolute_error: 0.1079
# Epoch 20/250
# 1785/1785 [==============================] - 1s 691us/step - loss: 3.5527e-04 - mean_absolute_error: 0.0206 - val_loss: 0.0133 - val_mean_absolute_error: 0.1096
# Epoch 21/250
# 1785/1785 [==============================] - 1s 664us/step - loss: 3.5267e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0131 - val_mean_absolute_error: 0.1090
# Epoch 22/250
# 1785/1785 [==============================] - 1s 694us/step - loss: 3.3836e-04 - mean_absolute_error: 0.0200 - val_loss: 0.0135 - val_mean_absolute_error: 0.1112
# Epoch 23/250
# 1785/1785 [==============================] - 1s 690us/step - loss: 3.3704e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0137 - val_mean_absolute_error: 0.1127
# Epoch 24/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 3.3087e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0142 - val_mean_absolute_error: 0.1153
# Epoch 25/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 3.2735e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0140 - val_mean_absolute_error: 0.1145
# Epoch 26/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 3.2467e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0142 - val_mean_absolute_error: 0.1158
# Epoch 27/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 3.2625e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0145 - val_mean_absolute_error: 0.1180
# Epoch 28/250
# 1785/1785 [==============================] - 1s 679us/step - loss: 3.3125e-04 - mean_absolute_error: 0.0197 - val_loss: 0.0144 - val_mean_absolute_error: 0.1170
# Epoch 29/250
# 1785/1785 [==============================] - 1s 711us/step - loss: 3.1863e-04 - mean_absolute_error: 0.0193 - val_loss: 0.0147 - val_mean_absolute_error: 0.1186
# Epoch 30/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 3.1516e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0150 - val_mean_absolute_error: 0.1206
# Epoch 31/250
# 1785/1785 [==============================] - 1s 687us/step - loss: 3.2546e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0151 - val_mean_absolute_error: 0.1217
# Epoch 32/250
# 1785/1785 [==============================] - 1s 666us/step - loss: 3.2516e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0150 - val_mean_absolute_error: 0.1208
# Epoch 33/250
# 1785/1785 [==============================] - 1s 676us/step - loss: 3.3573e-04 - mean_absolute_error: 0.0199 - val_loss: 0.0154 - val_mean_absolute_error: 0.1232
# Epoch 34/250
# 1785/1785 [==============================] - 1s 681us/step - loss: 3.1734e-04 - mean_absolute_error: 0.0193 - val_loss: 0.0154 - val_mean_absolute_error: 0.1231
# Epoch 35/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 3.0679e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0154 - val_mean_absolute_error: 0.1231
# Epoch 36/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 3.0873e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0154 - val_mean_absolute_error: 0.1225
# Epoch 37/250
# 1785/1785 [==============================] - 1s 666us/step - loss: 3.1303e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0155 - val_mean_absolute_error: 0.1235
# Epoch 38/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 3.0581e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0157 - val_mean_absolute_error: 0.1249
# Epoch 39/250
# 1785/1785 [==============================] - 1s 692us/step - loss: 3.0392e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0158 - val_mean_absolute_error: 0.1253
# Epoch 40/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 3.0145e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0159 - val_mean_absolute_error: 0.1258
# Epoch 41/250
# 1785/1785 [==============================] - 1s 674us/step - loss: 3.0088e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0160 - val_mean_absolute_error: 0.1262
# Epoch 42/250
# 1785/1785 [==============================] - 1s 695us/step - loss: 2.9935e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0160 - val_mean_absolute_error: 0.1269
# Epoch 43/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 3.0625e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0163 - val_mean_absolute_error: 0.1290
# Epoch 44/250
# 1785/1785 [==============================] - 1s 683us/step - loss: 3.1084e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0162 - val_mean_absolute_error: 0.1286
# Epoch 45/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 3.1159e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0164 - val_mean_absolute_error: 0.1294
# Epoch 46/250
# 1785/1785 [==============================] - 1s 674us/step - loss: 2.9927e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0164 - val_mean_absolute_error: 0.1295
# Epoch 47/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 3.0188e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0165 - val_mean_absolute_error: 0.1297
# Epoch 48/250
# 1785/1785 [==============================] - 1s 691us/step - loss: 2.9789e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0165 - val_mean_absolute_error: 0.1301
# Epoch 49/250
# 1785/1785 [==============================] - 1s 683us/step - loss: 2.9877e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0166 - val_mean_absolute_error: 0.1305
# Epoch 50/250
# 1785/1785 [==============================] - 1s 746us/step - loss: 2.9871e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0165 - val_mean_absolute_error: 0.1301
# Epoch 51/250
# 1785/1785 [==============================] - 1s 668us/step - loss: 2.9442e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0166 - val_mean_absolute_error: 0.1304
# Epoch 52/250
# 1785/1785 [==============================] - 1s 677us/step - loss: 2.9248e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0166 - val_mean_absolute_error: 0.1303
# Epoch 53/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 2.9065e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0167 - val_mean_absolute_error: 0.1308
# Epoch 54/250
# 1785/1785 [==============================] - 1s 669us/step - loss: 2.9143e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0167 - val_mean_absolute_error: 0.1304
# Epoch 55/250
# 1785/1785 [==============================] - 1s 676us/step - loss: 2.9252e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0170 - val_mean_absolute_error: 0.1321
# Epoch 56/250
# 1785/1785 [==============================] - 1s 674us/step - loss: 2.9256e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0167 - val_mean_absolute_error: 0.1303
# Epoch 57/250
# 1785/1785 [==============================] - 1s 728us/step - loss: 2.9463e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0169 - val_mean_absolute_error: 0.1317
# Epoch 58/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 2.9378e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0168 - val_mean_absolute_error: 0.1314
# Epoch 59/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 2.8754e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0169 - val_mean_absolute_error: 0.1321
# Epoch 60/250
# 1785/1785 [==============================] - 1s 703us/step - loss: 2.9129e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0172 - val_mean_absolute_error: 0.1343
# Epoch 61/250
# 1785/1785 [==============================] - 1s 713us/step - loss: 2.8799e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0170 - val_mean_absolute_error: 0.1330
# Epoch 62/250
# 1785/1785 [==============================] - 1s 685us/step - loss: 2.8903e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0171 - val_mean_absolute_error: 0.1340
# Epoch 63/250
# 1785/1785 [==============================] - 1s 681us/step - loss: 2.9809e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0173 - val_mean_absolute_error: 0.1348
# Epoch 64/250
# 1785/1785 [==============================] - 1s 709us/step - loss: 2.8470e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0171 - val_mean_absolute_error: 0.1333
# Epoch 65/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 2.8475e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0170 - val_mean_absolute_error: 0.1325
# Epoch 66/250
# 1785/1785 [==============================] - 1s 679us/step - loss: 2.8881e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0169 - val_mean_absolute_error: 0.1321
# Epoch 67/250
# 1785/1785 [==============================] - 1s 727us/step - loss: 2.9005e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0173 - val_mean_absolute_error: 0.1346
# Epoch 68/250
# 1785/1785 [==============================] - 1s 688us/step - loss: 2.8877e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0172 - val_mean_absolute_error: 0.1337
# Epoch 69/250
# 1785/1785 [==============================] - 1s 685us/step - loss: 2.8838e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0171 - val_mean_absolute_error: 0.1333
# Epoch 70/250
# 1785/1785 [==============================] - 1s 727us/step - loss: 2.8256e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0173 - val_mean_absolute_error: 0.1345
# Epoch 71/250
# 1785/1785 [==============================] - 1s 680us/step - loss: 2.7935e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0172 - val_mean_absolute_error: 0.1341
# Epoch 72/250
# 1785/1785 [==============================] - 1s 674us/step - loss: 2.8014e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0170 - val_mean_absolute_error: 0.1327
# Epoch 73/250
# 1785/1785 [==============================] - 1s 679us/step - loss: 2.8142e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0174 - val_mean_absolute_error: 0.1352
# Epoch 74/250
# 1785/1785 [==============================] - 1s 692us/step - loss: 2.8513e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0173 - val_mean_absolute_error: 0.1349
# Epoch 75/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 2.8841e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0171 - val_mean_absolute_error: 0.1335
# Epoch 76/250
# 1785/1785 [==============================] - 1s 751us/step - loss: 2.8388e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0173 - val_mean_absolute_error: 0.1346
# Epoch 77/250
# 1785/1785 [==============================] - 1s 662us/step - loss: 2.7875e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0173 - val_mean_absolute_error: 0.1347
# Epoch 78/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 2.7889e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0172 - val_mean_absolute_error: 0.1340
# Epoch 79/250
# 1785/1785 [==============================] - 1s 709us/step - loss: 2.7551e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0174 - val_mean_absolute_error: 0.1351
# Epoch 80/250
# 1785/1785 [==============================] - 1s 735us/step - loss: 2.8041e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0173 - val_mean_absolute_error: 0.1348
# Epoch 81/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 2.8444e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0175 - val_mean_absolute_error: 0.1358
# Epoch 82/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 2.8260e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0170 - val_mean_absolute_error: 0.1333
# Epoch 83/250
# 1785/1785 [==============================] - 1s 680us/step - loss: 2.7956e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0172 - val_mean_absolute_error: 0.1345
# Epoch 84/250
# 1785/1785 [==============================] - 1s 742us/step - loss: 2.7361e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0176 - val_mean_absolute_error: 0.1367
# Epoch 85/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 2.7572e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0173 - val_mean_absolute_error: 0.1351
# Epoch 86/250
# 1785/1785 [==============================] - 1s 679us/step - loss: 2.7321e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0172 - val_mean_absolute_error: 0.1340
# Epoch 87/250
# 1785/1785 [==============================] - 1s 659us/step - loss: 2.7880e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0173 - val_mean_absolute_error: 0.1349
# Epoch 88/250
# 1785/1785 [==============================] - 1s 664us/step - loss: 2.7341e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0174 - val_mean_absolute_error: 0.1360
# Epoch 89/250
# 1785/1785 [==============================] - 1s 658us/step - loss: 2.7842e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0176 - val_mean_absolute_error: 0.1375
# Epoch 90/250
# 1785/1785 [==============================] - 1s 662us/step - loss: 2.7516e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0173 - val_mean_absolute_error: 0.1356
# Epoch 91/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 2.7251e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0172 - val_mean_absolute_error: 0.1350
# Epoch 92/250
# 1785/1785 [==============================] - 1s 696us/step - loss: 2.7205e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0172 - val_mean_absolute_error: 0.1344
# Epoch 93/250
# 1785/1785 [==============================] - 1s 685us/step - loss: 2.7336e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0175 - val_mean_absolute_error: 0.1363
# Epoch 94/250
# 1785/1785 [==============================] - 1s 666us/step - loss: 2.6903e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0175 - val_mean_absolute_error: 0.1364
# Epoch 95/250
# 1785/1785 [==============================] - 1s 691us/step - loss: 2.6910e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0175 - val_mean_absolute_error: 0.1368
# Epoch 96/250
# 1785/1785 [==============================] - 1s 672us/step - loss: 2.7045e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0171 - val_mean_absolute_error: 0.1349
# Epoch 97/250
# 1785/1785 [==============================] - 1s 676us/step - loss: 2.7149e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0174 - val_mean_absolute_error: 0.1360
# Epoch 98/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 2.6774e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0175 - val_mean_absolute_error: 0.1367
# Epoch 99/250
# 1785/1785 [==============================] - 1s 653us/step - loss: 2.6802e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0172 - val_mean_absolute_error: 0.1346
# Epoch 100/250
# 1785/1785 [==============================] - 1s 658us/step - loss: 2.6939e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0169 - val_mean_absolute_error: 0.1335
# Epoch 101/250
# 1785/1785 [==============================] - 1s 710us/step - loss: 2.6679e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0175 - val_mean_absolute_error: 0.1373
# Epoch 102/250
# 1785/1785 [==============================] - 1s 724us/step - loss: 2.6703e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0176 - val_mean_absolute_error: 0.1373
# Epoch 103/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 2.6686e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0172 - val_mean_absolute_error: 0.1355
# Epoch 104/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 2.7001e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0171 - val_mean_absolute_error: 0.1349
# Epoch 105/250
# 1785/1785 [==============================] - 1s 657us/step - loss: 2.7153e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0171 - val_mean_absolute_error: 0.1345
# Epoch 106/250
# 1785/1785 [==============================] - 1s 660us/step - loss: 2.6971e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0174 - val_mean_absolute_error: 0.1360
# Epoch 107/250
# 1785/1785 [==============================] - 1s 687us/step - loss: 2.6615e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0173 - val_mean_absolute_error: 0.1358
# Epoch 108/250
# 1785/1785 [==============================] - 1s 683us/step - loss: 2.6324e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0172 - val_mean_absolute_error: 0.1351
# Epoch 109/250
# 1785/1785 [==============================] - 1s 694us/step - loss: 2.6666e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0173 - val_mean_absolute_error: 0.1356
# Epoch 110/250
# 1785/1785 [==============================] - 1s 676us/step - loss: 2.6809e-04 - mean_absolute_error: 0.0175 - val_loss: 0.0172 - val_mean_absolute_error: 0.1357
# Epoch 111/250
# 1785/1785 [==============================] - 1s 669us/step - loss: 2.6546e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0170 - val_mean_absolute_error: 0.1344
# Epoch 112/250
# 1785/1785 [==============================] - 1s 683us/step - loss: 2.6284e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0172 - val_mean_absolute_error: 0.1357
# Epoch 113/250
# 1785/1785 [==============================] - 1s 679us/step - loss: 2.6364e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0174 - val_mean_absolute_error: 0.1367
# Epoch 114/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 2.6323e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0173 - val_mean_absolute_error: 0.1361
# Epoch 115/250
# 1785/1785 [==============================] - 1s 652us/step - loss: 2.6168e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0170 - val_mean_absolute_error: 0.1345
# Epoch 116/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 2.6005e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0170 - val_mean_absolute_error: 0.1348
# Epoch 117/250
# 1785/1785 [==============================] - 1s 662us/step - loss: 2.6118e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0172 - val_mean_absolute_error: 0.1358
# Epoch 118/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 2.6109e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0173 - val_mean_absolute_error: 0.1369
# Epoch 119/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 2.6073e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0171 - val_mean_absolute_error: 0.1358
# Epoch 120/250
# 1785/1785 [==============================] - 1s 674us/step - loss: 2.6410e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0171 - val_mean_absolute_error: 0.1353
# Epoch 121/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 2.6064e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0173 - val_mean_absolute_error: 0.1366
# Epoch 122/250
# 1785/1785 [==============================] - 1s 677us/step - loss: 2.6051e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0171 - val_mean_absolute_error: 0.1353
# Epoch 123/250
# 1785/1785 [==============================] - 1s 702us/step - loss: 2.6142e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0168 - val_mean_absolute_error: 0.1335
# Epoch 124/250
# 1785/1785 [==============================] - 1s 700us/step - loss: 2.5751e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0168 - val_mean_absolute_error: 0.1335
# Epoch 125/250
# 1785/1785 [==============================] - 1s 691us/step - loss: 2.5647e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0172 - val_mean_absolute_error: 0.1366
# Epoch 126/250
# 1785/1785 [==============================] - 1s 717us/step - loss: 2.5677e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0172 - val_mean_absolute_error: 0.1367
# Epoch 127/250
# 1785/1785 [==============================] - 1s 717us/step - loss: 2.6375e-04 - mean_absolute_error: 0.0173 - val_loss: 0.0168 - val_mean_absolute_error: 0.1343
# Epoch 128/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 2.5924e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0170 - val_mean_absolute_error: 0.1348
# Epoch 129/250
# 1785/1785 [==============================] - 1s 661us/step - loss: 2.5590e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0170 - val_mean_absolute_error: 0.1353
# Epoch 130/250
# 1785/1785 [==============================] - 1s 677us/step - loss: 2.5540e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0168 - val_mean_absolute_error: 0.1344
# Epoch 131/250
# 1785/1785 [==============================] - 1s 672us/step - loss: 2.5483e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0168 - val_mean_absolute_error: 0.1346
# Epoch 132/250
# 1785/1785 [==============================] - 1s 672us/step - loss: 2.5670e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0173 - val_mean_absolute_error: 0.1377
# Epoch 133/250
# 1785/1785 [==============================] - 1s 693us/step - loss: 2.5633e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0169 - val_mean_absolute_error: 0.1353
# Epoch 134/250
# 1785/1785 [==============================] - 1s 672us/step - loss: 2.5731e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0166 - val_mean_absolute_error: 0.1332
# Epoch 135/250
# 1785/1785 [==============================] - 1s 699us/step - loss: 2.5336e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0168 - val_mean_absolute_error: 0.1345
# Epoch 136/250
# 1785/1785 [==============================] - 2s 847us/step - loss: 2.5348e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0173 - val_mean_absolute_error: 0.1375
# Epoch 137/250
# 1785/1785 [==============================] - 1s 671us/step - loss: 2.5449e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0168 - val_mean_absolute_error: 0.1346
# Epoch 138/250
# 1785/1785 [==============================] - 1s 672us/step - loss: 2.5204e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0167 - val_mean_absolute_error: 0.1339
# Epoch 139/250
# 1785/1785 [==============================] - 1s 706us/step - loss: 2.5146e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0169 - val_mean_absolute_error: 0.1345
# Epoch 140/250
# 1785/1785 [==============================] - 1s 691us/step - loss: 2.5545e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0166 - val_mean_absolute_error: 0.1332
# Epoch 141/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 2.5639e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0168 - val_mean_absolute_error: 0.1348
# Epoch 142/250
# 1785/1785 [==============================] - 1s 669us/step - loss: 2.5228e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0169 - val_mean_absolute_error: 0.1354
# Epoch 143/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 2.5361e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0166 - val_mean_absolute_error: 0.1336
# Epoch 144/250
# 1785/1785 [==============================] - 1s 688us/step - loss: 2.5098e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0165 - val_mean_absolute_error: 0.1324
# Epoch 145/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 2.4928e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0167 - val_mean_absolute_error: 0.1343
# Epoch 146/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 2.5383e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0166 - val_mean_absolute_error: 0.1338
# Epoch 147/250
# 1785/1785 [==============================] - 1s 686us/step - loss: 2.4911e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0167 - val_mean_absolute_error: 0.1342
# Epoch 148/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 2.4767e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0166 - val_mean_absolute_error: 0.1337
# Epoch 149/250
# 1785/1785 [==============================] - 1s 742us/step - loss: 2.4923e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0165 - val_mean_absolute_error: 0.1330
# Epoch 150/250
# 1785/1785 [==============================] - 1s 696us/step - loss: 2.4933e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0163 - val_mean_absolute_error: 0.1323
# Epoch 151/250
# 1785/1785 [==============================] - 1s 725us/step - loss: 2.4983e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0166 - val_mean_absolute_error: 0.1340
# Epoch 152/250
# 1785/1785 [==============================] - 1s 690us/step - loss: 2.4638e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0165 - val_mean_absolute_error: 0.1333
# Epoch 153/250
# 1785/1785 [==============================] - 1s 739us/step - loss: 2.4606e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0164 - val_mean_absolute_error: 0.1330
# Epoch 154/250
# 1785/1785 [==============================] - 1s 701us/step - loss: 2.4499e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0167 - val_mean_absolute_error: 0.1347
# Epoch 155/250
# 1785/1785 [==============================] - 1s 709us/step - loss: 2.4897e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0167 - val_mean_absolute_error: 0.1350
# Epoch 156/250
# 1785/1785 [==============================] - 1s 712us/step - loss: 2.5076e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0162 - val_mean_absolute_error: 0.1313
# Epoch 157/250
# 1785/1785 [==============================] - 1s 669us/step - loss: 2.4570e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0163 - val_mean_absolute_error: 0.1325
# Epoch 158/250
# 1785/1785 [==============================] - 1s 687us/step - loss: 2.4396e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0163 - val_mean_absolute_error: 0.1326
# Epoch 159/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 2.4406e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0163 - val_mean_absolute_error: 0.1325
# Epoch 160/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 2.4930e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0163 - val_mean_absolute_error: 0.1323
# Epoch 161/250
# 1785/1785 [==============================] - 1s 680us/step - loss: 2.5316e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0160 - val_mean_absolute_error: 0.1306
# Epoch 162/250
# 1785/1785 [==============================] - 1s 679us/step - loss: 2.4713e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0163 - val_mean_absolute_error: 0.1329
# Epoch 163/250
# 1785/1785 [==============================] - 1s 676us/step - loss: 2.4940e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0167 - val_mean_absolute_error: 0.1351
# Epoch 164/250
# 1785/1785 [==============================] - 1s 706us/step - loss: 2.4478e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0161 - val_mean_absolute_error: 0.1315
# Epoch 165/250
# 1785/1785 [==============================] - 1s 777us/step - loss: 2.4298e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0160 - val_mean_absolute_error: 0.1311
# Epoch 166/250
# 1785/1785 [==============================] - 1s 703us/step - loss: 2.4380e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0163 - val_mean_absolute_error: 0.1329
# Epoch 167/250
# 1785/1785 [==============================] - 1s 694us/step - loss: 2.4166e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0163 - val_mean_absolute_error: 0.1329
# Epoch 168/250
# 1785/1785 [==============================] - 1s 715us/step - loss: 2.4372e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0160 - val_mean_absolute_error: 0.1311
# Epoch 169/250
# 1785/1785 [==============================] - 1s 701us/step - loss: 2.5121e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0162 - val_mean_absolute_error: 0.1329
# Epoch 170/250
# 1785/1785 [==============================] - 1s 720us/step - loss: 2.6287e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0165 - val_mean_absolute_error: 0.1347
# Epoch 171/250
# 1785/1785 [==============================] - 1s 752us/step - loss: 2.5174e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0162 - val_mean_absolute_error: 0.1322
# Epoch 172/250
# 1785/1785 [==============================] - 1s 736us/step - loss: 2.4113e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0160 - val_mean_absolute_error: 0.1311
# Epoch 173/250
# 1785/1785 [==============================] - 1s 706us/step - loss: 2.3920e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0161 - val_mean_absolute_error: 0.1315
# Epoch 174/250
# 1785/1785 [==============================] - 1s 677us/step - loss: 2.3858e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0160 - val_mean_absolute_error: 0.1312
# Epoch 175/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 2.4057e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0160 - val_mean_absolute_error: 0.1311
# Epoch 176/250
# 1785/1785 [==============================] - 1s 685us/step - loss: 2.3867e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0158 - val_mean_absolute_error: 0.1303
# Epoch 177/250
# 1785/1785 [==============================] - 1s 680us/step - loss: 2.3693e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0160 - val_mean_absolute_error: 0.1312
# Epoch 178/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 2.3772e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0161 - val_mean_absolute_error: 0.1323
# Epoch 179/250
# 1785/1785 [==============================] - 1s 676us/step - loss: 2.3702e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0158 - val_mean_absolute_error: 0.1302
# Epoch 180/250
# 1785/1785 [==============================] - 1s 674us/step - loss: 2.3855e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0158 - val_mean_absolute_error: 0.1305
# Epoch 181/250
# 1785/1785 [==============================] - 1s 669us/step - loss: 2.4520e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0160 - val_mean_absolute_error: 0.1318
# Epoch 182/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 2.4358e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0158 - val_mean_absolute_error: 0.1309
# Epoch 183/250
# 1785/1785 [==============================] - 1s 677us/step - loss: 2.3793e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0159 - val_mean_absolute_error: 0.1311
# Epoch 184/250
# 1785/1785 [==============================] - 1s 662us/step - loss: 2.3610e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0159 - val_mean_absolute_error: 0.1314
# Epoch 185/250
# 1785/1785 [==============================] - 1s 681us/step - loss: 2.3778e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0158 - val_mean_absolute_error: 0.1306
# Epoch 186/250
# 1785/1785 [==============================] - 1s 736us/step - loss: 2.3507e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0156 - val_mean_absolute_error: 0.1295
# Epoch 187/250
# 1785/1785 [==============================] - 1s 682us/step - loss: 2.3704e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0156 - val_mean_absolute_error: 0.1294
# Epoch 188/250
# 1785/1785 [==============================] - 1s 761us/step - loss: 2.3511e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0158 - val_mean_absolute_error: 0.1307
# Epoch 189/250
# 1785/1785 [==============================] - 1s 716us/step - loss: 2.3723e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0159 - val_mean_absolute_error: 0.1316
# Epoch 190/250
# 1785/1785 [==============================] - 1s 676us/step - loss: 2.3798e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0157 - val_mean_absolute_error: 0.1299
# Epoch 191/250
# 1785/1785 [==============================] - 1s 709us/step - loss: 2.3455e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0157 - val_mean_absolute_error: 0.1301
# Epoch 192/250
# 1785/1785 [==============================] - 1s 657us/step - loss: 2.3316e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0156 - val_mean_absolute_error: 0.1296
# Epoch 193/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 2.3396e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0155 - val_mean_absolute_error: 0.1291
# Epoch 194/250
# 1785/1785 [==============================] - 1s 683us/step - loss: 2.3291e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0159 - val_mean_absolute_error: 0.1317
# Epoch 195/250
# 1785/1785 [==============================] - 1s 705us/step - loss: 2.3594e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0156 - val_mean_absolute_error: 0.1291
# Epoch 196/250
# 1785/1785 [==============================] - 1s 670us/step - loss: 2.3374e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0152 - val_mean_absolute_error: 0.1271
# Epoch 197/250
# 1785/1785 [==============================] - 1s 672us/step - loss: 2.3295e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0155 - val_mean_absolute_error: 0.1290
# Epoch 198/250
# 1785/1785 [==============================] - 1s 719us/step - loss: 2.3341e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0157 - val_mean_absolute_error: 0.1304
# Epoch 199/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 2.3089e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0155 - val_mean_absolute_error: 0.1289
# Epoch 200/250
# 1785/1785 [==============================] - 1s 663us/step - loss: 2.3594e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0154 - val_mean_absolute_error: 0.1289
# Epoch 201/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 2.3320e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0156 - val_mean_absolute_error: 0.1304
# Epoch 202/250
# 1785/1785 [==============================] - 1s 693us/step - loss: 2.3227e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0156 - val_mean_absolute_error: 0.1301
# Epoch 203/250
# 1785/1785 [==============================] - 1s 687us/step - loss: 2.3246e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0154 - val_mean_absolute_error: 0.1296
# Epoch 204/250
# 1785/1785 [==============================] - 1s 705us/step - loss: 2.3215e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0155 - val_mean_absolute_error: 0.1295
# Epoch 205/250
# 1785/1785 [==============================] - 1s 705us/step - loss: 2.2854e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0152 - val_mean_absolute_error: 0.1283
# Epoch 206/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 2.3202e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0154 - val_mean_absolute_error: 0.1301
# Epoch 207/250
# 1785/1785 [==============================] - 1s 687us/step - loss: 2.3492e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0156 - val_mean_absolute_error: 0.1304
# Epoch 208/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 2.2820e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0152 - val_mean_absolute_error: 0.1282
# Epoch 209/250
# 1785/1785 [==============================] - 1s 673us/step - loss: 2.2665e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0150 - val_mean_absolute_error: 0.1268
# Epoch 210/250
# 1785/1785 [==============================] - 1s 672us/step - loss: 2.2721e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0152 - val_mean_absolute_error: 0.1279
# Epoch 211/250
# 1785/1785 [==============================] - 1s 683us/step - loss: 2.2750e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0152 - val_mean_absolute_error: 0.1278
# Epoch 212/250
# 1785/1785 [==============================] - 1s 695us/step - loss: 2.2614e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0151 - val_mean_absolute_error: 0.1273
# Epoch 213/250
# 1785/1785 [==============================] - 1s 693us/step - loss: 2.2823e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0151 - val_mean_absolute_error: 0.1273
# Epoch 214/250
# 1785/1785 [==============================] - 1s 720us/step - loss: 2.2845e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0153 - val_mean_absolute_error: 0.1292
# Epoch 215/250
# 1785/1785 [==============================] - 1s 694us/step - loss: 2.2492e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0151 - val_mean_absolute_error: 0.1277
# Epoch 216/250
# 1785/1785 [==============================] - 1s 672us/step - loss: 2.2766e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0149 - val_mean_absolute_error: 0.1264
# Epoch 217/250
# 1785/1785 [==============================] - 1s 679us/step - loss: 2.2536e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0151 - val_mean_absolute_error: 0.1276
# Epoch 218/250
# 1785/1785 [==============================] - 1s 699us/step - loss: 2.2716e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0152 - val_mean_absolute_error: 0.1280
# Epoch 219/250
# 1785/1785 [==============================] - 1s 719us/step - loss: 2.2461e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0149 - val_mean_absolute_error: 0.1263
# Epoch 220/250
# 1785/1785 [==============================] - 1s 659us/step - loss: 2.2457e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0148 - val_mean_absolute_error: 0.1258
# Epoch 221/250
# 1785/1785 [==============================] - 1s 683us/step - loss: 2.2648e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0153 - val_mean_absolute_error: 0.1291
# Epoch 222/250
# 1785/1785 [==============================] - 1s 675us/step - loss: 2.2815e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0150 - val_mean_absolute_error: 0.1275
# Epoch 223/250
# 1785/1785 [==============================] - 1s 711us/step - loss: 2.2791e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0146 - val_mean_absolute_error: 0.1251
# Epoch 224/250
# 1785/1785 [==============================] - 1s 674us/step - loss: 2.2244e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0148 - val_mean_absolute_error: 0.1264
# Epoch 225/250
# 1785/1785 [==============================] - 1s 710us/step - loss: 2.2476e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0152 - val_mean_absolute_error: 0.1287
# Epoch 226/250
# 1785/1785 [==============================] - 1s 672us/step - loss: 2.3036e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0149 - val_mean_absolute_error: 0.1261
# Epoch 227/250
# 1785/1785 [==============================] - 1s 681us/step - loss: 2.3470e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0146 - val_mean_absolute_error: 0.1246
# Epoch 228/250
# 1785/1785 [==============================] - 1s 666us/step - loss: 2.2561e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0148 - val_mean_absolute_error: 0.1262
# Epoch 229/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 2.2068e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0147 - val_mean_absolute_error: 0.1256
# Epoch 230/250
# 1785/1785 [==============================] - 1s 684us/step - loss: 2.2141e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0147 - val_mean_absolute_error: 0.1253
# Epoch 231/250
# 1785/1785 [==============================] - 1s 720us/step - loss: 2.2010e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0147 - val_mean_absolute_error: 0.1254
# Epoch 232/250
# 1785/1785 [==============================] - 1s 712us/step - loss: 2.2068e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0148 - val_mean_absolute_error: 0.1264
# Epoch 233/250
# 1785/1785 [==============================] - 1s 667us/step - loss: 2.2406e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0146 - val_mean_absolute_error: 0.1252
# Epoch 234/250
# 1785/1785 [==============================] - 1s 661us/step - loss: 2.2021e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0147 - val_mean_absolute_error: 0.1260
# Epoch 235/250
# 1785/1785 [==============================] - 1s 728us/step - loss: 2.1954e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0146 - val_mean_absolute_error: 0.1251
# Epoch 236/250
# 1785/1785 [==============================] - 1s 677us/step - loss: 2.1886e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0148 - val_mean_absolute_error: 0.1271
# Epoch 237/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 2.2185e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0147 - val_mean_absolute_error: 0.1266
# Epoch 238/250
# 1785/1785 [==============================] - 1s 666us/step - loss: 2.2416e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0145 - val_mean_absolute_error: 0.1254
# Epoch 239/250
# 1785/1785 [==============================] - 1s 714us/step - loss: 2.1951e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0146 - val_mean_absolute_error: 0.1262
# Epoch 240/250
# 1785/1785 [==============================] - 1s 660us/step - loss: 2.2963e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0144 - val_mean_absolute_error: 0.1244
# Epoch 241/250
# 1785/1785 [==============================] - 1s 680us/step - loss: 2.3025e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0146 - val_mean_absolute_error: 0.1248
# Epoch 242/250
# 1785/1785 [==============================] - 1s 750us/step - loss: 2.3234e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0146 - val_mean_absolute_error: 0.1247
# Epoch 243/250
# 1785/1785 [==============================] - 1s 678us/step - loss: 2.2655e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0144 - val_mean_absolute_error: 0.1241
# Epoch 244/250
# 1785/1785 [==============================] - 1s 690us/step - loss: 2.1666e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0145 - val_mean_absolute_error: 0.1248
# Epoch 245/250
# 1785/1785 [==============================] - 1s 665us/step - loss: 2.1715e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0143 - val_mean_absolute_error: 0.1235
# Epoch 246/250
# 1785/1785 [==============================] - 1s 664us/step - loss: 2.1526e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0145 - val_mean_absolute_error: 0.1251
# Epoch 247/250
# 1785/1785 [==============================] - 1s 658us/step - loss: 2.1721e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0145 - val_mean_absolute_error: 0.1248
# Epoch 248/250
# 1785/1785 [==============================] - 1s 660us/step - loss: 2.2043e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0143 - val_mean_absolute_error: 0.1234
# Epoch 249/250
# 1785/1785 [==============================] - 1s 685us/step - loss: 2.1728e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0144 - val_mean_absolute_error: 0.1242
# Epoch 250/250
# 1785/1785 [==============================] - 1s 680us/step - loss: 2.1552e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0146 - val_mean_absolute_error: 0.1257

# %% [markdown]
# Once we predict the values, we also must *reverse* the normalization so that we can plot the predictions in the same scale as the original values.

# %%
y_pred_train_keras = scaler.inverse_transform(keras_model.predict(X_train_reshape, batch_size=256))
y_pred_keras = scaler.inverse_transform(keras_model.predict(X_test_reshape, batch_size=256))

# %% [markdown]
# Let's now plot what the training and test predictions look like and compare witht he original values.

# %%
# Plot what it looks like for the training data
df_keras = df.copy()
df_keras.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_keras = df_keras.iloc[window_size:ind_split] # Past 32 days we don't know yet
df_keras['Adj Close Train'] = y_pred_train_keras[:-window_size]
df_keras.plot(label='MSI', figsize=(16,4), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Again, quite accurate... and now for the test data.

# %%
# Same for the test
df_keras = df.copy()
df_keras.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_keras = df_keras.iloc[ind_split+window_size:] # Past 32 days we don't know yet
df_keras['Adj Close Test'] = y_pred_keras
df_keras.plot(label='TSLA', figsize=(16,4), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# I have more confidence in the neural network approach as it seems to indicate would the trend would be like when the data is noise free.  We can also see a more smoother transition between points of high curvature.
#
# Finally to see how everything performs, let's plot all of the methods together for both the training and testing data.

# %%
df_train = df.copy()
df_train.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_train = df_train.iloc[window_size:ind_split] # Past 32 days we don't know yet
# Add in all of our methods
df_train['Adj Close Train Ridge'] = y_pred_train_ridge[:-window_size]
df_train['Adj Close Train Lasso'] = y_pred_train_lasso[:-window_size]
df_train['Adj Close Train LarsLasso'] = y_pred_train_larslasso[:-window_size]
df_train['Adj Close Train Gradient Boosting'] = y_pred_train_gb[:-window_size]
df_train['Adj Close Train LSTM'] = y_pred_train_keras[:-window_size]
# Plot the data now
df_train.plot(label='MSI', figsize=(16,4), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# Cool.  They all more or less follow the same trend... and now for the testing data.

# %%
df_test = df.copy()
df_test.drop(['Open', 'High', 'Low', 'Close', 'Volume'], axis=1, inplace=True)
df_test = df_test.iloc[ind_split+window_size:] # Past 32 days we don't know yet
# Add in all of our methods
df_test['Adj Close Test Ridge'] = y_pred_ridge
df_test['Adj Close Test Lasso'] = y_pred_lasso
df_test['Adj Close Test LarsLasso'] = y_pred_larslasso
df_test['Adj Close Test Gradient Boosting'] = y_pred_gb
df_test['Adj Close Test LSTM'] = y_pred_keras
# Plot the data now
df_test.plot(label='MSI', figsize=(16,4), title='Adjusted Closing Price', grid=True)

# %% [markdown]
# # So what happens if we don't have testing data to try out?
#
# Good question.  What you can do take the learned model that you have, then start with the last $N$ values in your data (in my case 32), and start predicting what the next values will be.  With the next values, keep using the previous $N$ values for your desired forecasting.
#
# We already have our learned models above, so let's go ahead and do that.

# %%
num_days = 10 # Let's try and forecase the next 10 days or two years

# Get the last window_size (32) days
data_seed = df['Adj Close'].values[-window_size:][None]
# Get the normalized data as well for the neural network
data_seed_norm = scaler.transform(data_seed)
input_values = {"ridge": data_seed, "lasso": data_seed,"larslasso": data_seed, "gb": data_seed, "keras": data_seed_norm.copy()}
values = {"ridge": [], "lasso":[],"larslasso":[], "gb": [], "keras": []}
for i in range(num_days): # For each day...
    # Predict the next price given the previous N prices
    values["ridge"].append(ridge_model.predict(input_values["ridge"])[0])
    values["lasso"].append(lasso_model.predict(input_values["lasso"])[0])
    values["larslasso"].append(larslasso_model.predict(input_values["larslasso"])[0])
    values["gb"].append(gb_model.predict(input_values["gb"])[0])
    values["keras"].append(keras_model.predict(input_values["keras"][...,None])[0][0])

    # Dump the oldest price and put the newest price at the end
    for v in input_values:
        val = input_values[v]
        val = np.insert(val, -1, values[v][-1], axis=1)
        val = np.delete(val, 0, axis=1)
        input_values[v] = val.copy()

# Convert all to NumPy arrays
for v in input_values:
    values[v] = np.array(values[v])

# Unnormalize prices from NN approach
values["keras"] = scaler.inverse_transform(values["keras"][None])[0]

# %% [markdown]
# Now let's plot the next 10 days worth of data

# %%
from datetime import timedelta, datetime
last_date = datetime.strptime(df.index[-1], '%Y-%m-%d')
df_forecast = pd.DataFrame()
df_forecast["Ridge"] = values["ridge"]
df_forecast["Lasso"] = values["lasso"]
df_forecast["LarsLasso"] = values["larslasso"]
df_forecast["Gradient Boosting"] = values["gb"]
df_forecast["Keras LSTM"] = values["keras"]
df_forecast.index = pd.date_range(start=last_date, periods=num_days)
df_forecast.plot(label='MSI', figsize=(16,4), title='Forecasted Adjusted Closing Price', grid=True)
